# %% [markdown]
# # Fairness Indicators Example Jupyter

# %% [markdown]
# ## Overview
#
# In this activity, you'll use Fairness Indicators to explore the Civil Comments dataset. Fairness Indicators is a suite of tools built on top of [TensorFlow Model Analysis](https://www.tensorflow.org/tfx/model_analysis/get_started) that enable regular evaluation of fairness metrics in product pipelines. This [Introductory Video](https://www.youtube.com/watch?v=pHT-ImFXPQo) provides more details and context on the real-world scenario we are presenting here, one of primary motivations for creating Fairness Indicators.
#
# ## About the Dataset
#
# In this exercise, you'll work with the [Civil Comments dataset](https://www.kaggle.com/c/jigsaw-unintended-bias-in-toxicity-classification), approximately 2 million public comments made public by the [Civil Comments platform](https://medium.com/@aja_15265/saying-goodbye-to-civil-comments-41859d3a2b1d) in 2017 for ongoing research. This effort was sponsored by Jigsaw, who have hosted competitions on Kaggle to help classify toxic comments as well as minimize unintended model bias.
#
# Each individual text comment in the dataset has a toxicity label. Within the data, a subset of comments are labeled with a variety of identity attributes, including categories for gender, sexual orientation, religion, and race or ethnicity.
#
# ## About the Tools
#
# [TensorFlow Model Analysis](https://www.tensorflow.org/tfx/model_analysis/get_started) is a library for evaluating both TensorFlow and non-TensorFlow machine learning models. It allows users to evaluate their models on large amounts of data in a distributed manner, computing in-graph and other metrics over different slices of data and visualized in notebooks.
#
# Fairness Indicators is built on top of TFMA. With Fairness Indicators, users will be able to:
#
# * Evaluate model performance, sliced across defined groups of users
# * Feel confident about results with confidence intervals and evaluations at multiple thresholds
#
# Fairness Indicators is packaged with [TensorFlow Data Validation](https://www.tensorflow.org/tfx/data_validation/get_started) and [What-If Tool](https://pair-code.github.io/what-if-tool/) to allow users to:
#
# * Evaluate the distribution of datasets
# * Dive deep into individual slices to explore root causes and opportunities for improvement with the What-If Tool

# %% [markdown]
# # Importing
#
# Run the following code to install the fairness_indicators library. This package contains the tools we'll be using in this exercise. Restart Runtime may be requested but is not necessary.

# %%
# !pip install fairness-indicators
# Out:
# Requirement already satisfied: fairness-indicators in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (0.1.0.dev5)
# Requirement already satisfied: setuptools>=40.2.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (45.0.0)
# Requirement already satisfied: tensorflow-model-analysis<1,>=0.15.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (0.16.0.dev0)
# Requirement already satisfied: tensorflow-data-validation<1,>=0.15.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (0.15.0)
# Requirement already satisfied: witwidget<2,>=1.4.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (1.5.1)
# Requirement already satisfied: tensorflow<3,>=1.15 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (2.1.0)
# Requirement already satisfied: tensorboard<2,>=1.14.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (1.15.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fairness-indicators) (0.33.6)
# Requirement already satisfied: ipywidgets<8,>=7 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (7.5.1)
# Requirement already satisfied: jupyter<2,>=1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.0.0)
# Requirement already satisfied: protobuf<4,>=3.7 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.11.2)
# Requirement already satisfied: six<2,>=1.12 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.13.0)
# Requirement already satisfied: tfx-bsl<0.17,>=0.15.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.15.3)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.16 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.17.0)
# Requirement already satisfied: numpy<2,>=1.16 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.18.1)
# Collecting scipy==1.1.0
#   Using cached https://files.pythonhosted.org/packages/40/de/0c22c6754370ba6b1fa8e53bd6e514d4a41a181125d405a501c215cbdbd6/scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied: ipython>=5 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (7.11.1)
# Requirement already satisfied: pandas<1,>=0.24 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.25.3)
# Requirement already satisfied: scikit-learn<0.22,>=0.18 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.21.3)
# Requirement already satisfied: tensorflow-transform<0.16,>=0.15 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.15.0)
# Requirement already satisfied: pyarrow<0.15,>=0.14 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.14.1)
# Requirement already satisfied: absl-py<0.9,>=0.7 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.8.1)
# Requirement already satisfied: tensorflow-metadata<0.16,>=0.15 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.15.2)
# Requirement already satisfied: joblib<0.15,>=0.12 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.14.1)
# Requirement already satisfied: oauth2client>=4.1.3 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from witwidget<2,>=1.4.4->fairness-indicators) (4.1.3)
# Requirement already satisfied: tensorflow-serving-api>=1.12.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from witwidget<2,>=1.4.4->fairness-indicators) (2.0.0)
# Requirement already satisfied: google-api-python-client>=1.7.8 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from witwidget<2,>=1.4.4->fairness-indicators) (1.7.11)
# Requirement already satisfied: google-pasta>=0.1.6 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (0.1.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (1.11.2)
# Requirement already satisfied: gast==0.2.2 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (0.2.2)
# Requirement already satisfied: astor>=0.6.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (0.8.1)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (2.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (1.26.0)
# Requirement already satisfied: keras-applications>=1.0.8 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow<3,>=1.15->fairness-indicators) (1.0.8)
# Requirement already satisfied: markdown>=2.6.8 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorboard<2,>=1.14.0->fairness-indicators) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorboard<2,>=1.14.0->fairness-indicators) (0.16.0)
# Requirement already satisfied: nbformat>=4.2.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (5.0.3)
# Requirement already satisfied: ipykernel>=4.5.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (4.3.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.5.1)
# Requirement already satisfied: nbconvert in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (5.6.1)
# Requirement already satisfied: jupyter-console in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (6.0.0)
# Requirement already satisfied: notebook in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (6.0.2)
# Requirement already satisfied: qtconsole in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (4.6.0)
# Requirement already satisfied: psutil<6,>=5.6 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tfx-bsl<0.17,>=0.15.1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (5.6.7)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.10.1)
# Requirement already satisfied: httplib2<=0.12.0,>=0.8 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.12.0)
# Requirement already satisfied: future<1.0.0,>=0.16.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.18.2)
# Requirement already satisfied: avro-python3<2.0.0,>=1.8.1; python_version >= "3.0" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.9.1)
# Requirement already satisfied: dill<0.3.1,>=0.3.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.3.0)
# Requirement already satisfied: fastavro<0.22,>=0.21.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.21.24)
# Requirement already satisfied: crcmod<2.0,>=1.7 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.7)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.5.8)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.8.1)
# Requirement already satisfied: pytz>=2018.3 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2019.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.4.1)
# Requirement already satisfied: google-cloud-core<2,>=0.28.1; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.1.0)
# Requirement already satisfied: google-apitools<0.5.29,>=0.5.28; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.5.28)
# Requirement already satisfied: cachetools<4,>=3.1.0; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.1.1)
# Requirement already satisfied: google-cloud-bigtable<1.1.0,>=0.31.1; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.0.0)
# Requirement already satisfied: google-cloud-pubsub<1.1.0,>=0.39.0; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.0.2)
# Requirement already satisfied: google-cloud-bigquery<1.18.0,>=1.6.0; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.17.1)
# Requirement already satisfied: google-cloud-datastore<1.8.0,>=1.7.1; extra == "gcp" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.7.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (2.0.10)
# Requirement already satisfied: pygments in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (2.5.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (4.7.0)
# Requirement already satisfied: backcall in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.1.0)
# Requirement already satisfied: pickleshare in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.15.2)
# Requirement already satisfied: decorator in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (4.4.1)
# Requirement already satisfied: googleapis-common-protos in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from tensorflow-metadata<0.16,>=0.15->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (1.6.0)
# Requirement already satisfied: pyasn1>=0.1.7 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from oauth2client>=4.1.3->witwidget<2,>=1.4.4->fairness-indicators) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from oauth2client>=4.1.3->witwidget<2,>=1.4.4->fairness-indicators) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from oauth2client>=4.1.3->witwidget<2,>=1.4.4->fairness-indicators) (0.2.8)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-api-python-client>=1.7.8->witwidget<2,>=1.4.4->fairness-indicators) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-api-python-client>=1.7.8->witwidget<2,>=1.4.4->fairness-indicators) (3.0.1)
# Requirement already satisfied: google-auth>=1.4.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-api-python-client>=1.7.8->witwidget<2,>=1.4.4->fairness-indicators) (1.10.0)
# Requirement already satisfied: h5py in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow<3,>=1.15->fairness-indicators) (2.10.0)
# Requirement already satisfied: jupyter-core in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (4.6.1)
# Requirement already satisfied: ipython-genutils in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.2.0)
# Requirement already satisfied: tornado>=4.2 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (6.0.3)
# Requirement already satisfied: jupyter-client in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (5.3.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.8.4)
# Requirement already satisfied: testpath in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.3)
# Requirement already satisfied: jinja2>=2.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.10.3)
# Requirement already satisfied: defusedxml in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.6.0)
# Requirement already satisfied: bleach in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.4.2)
# Requirement already satisfied: pyzmq>=17 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (18.1.1)
# Requirement already satisfied: terminado>=0.8.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.8.3)
# Requirement already satisfied: prometheus-client in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.7.1)
# Requirement already satisfied: Send2Trash in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.5.0)
# Requirement already satisfied: docopt in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.22.0)
# Requirement already satisfied: pbr>=0.11 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (5.4.4)
# Requirement already satisfied: pyparsing>=2.1.4 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from pydot<2,>=1.2.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.4.6)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-cloud-core<2,>=0.28.1; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.16.0)
# Requirement already satisfied: fasteners>=0.14 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-apitools<0.5.29,>=0.5.28; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.15)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-cloud-bigtable<1.1.0,>=0.31.1; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.12.3)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from google-cloud-bigquery<1.18.0,>=1.6.0; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.4.1)
# Requirement already satisfied: wcwidth in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.1.8)
# Requirement already satisfied: ptyprocess>=0.5 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.6.0)
# Requirement already satisfied: parso>=0.5.2 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5->tensorflow-data-validation<1,>=0.15.0->fairness-indicators) (0.5.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (19.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.1.1)
# Requirement already satisfied: webencodings in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from bleach->nbconvert->jupyter<2,>=1->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (0.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.25.7)
# Requirement already satisfied: idna<2.9,>=2.5 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (3.0.4)
# Requirement already satisfied: monotonic>=0.1 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from fasteners>=0.14->google-apitools<0.5.29,>=0.5.28; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.5)
# Requirement already satisfied: zipp>=0.5 in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (1.0.0)
# Requirement already satisfied: more-itertools in ./.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<1,>=0.15.4->fairness-indicators) (8.1.0)
# ERROR: tensorflow 2.1.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.1.0 which is incompatible.
# ERROR: tensorflow 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow-serving-api 2.0.0 has requirement tensorflow~=2.0.0, but you'll have tensorflow 2.1.0 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed scipy-1.1.0

# %%
import os
import tempfile
import apache_beam as beam
import numpy as np
import pandas as pd
from datetime import datetime

import tensorflow_hub as hub
import tensorflow as tf
import tensorflow_model_analysis as tfma
import tensorflow_data_validation as tfdv
from tensorflow_model_analysis.addons.fairness.post_export_metrics import fairness_indicators
from tensorflow_model_analysis.addons.fairness.view import widget_view
from fairness_indicators.examples import util

from witwidget.notebook.visualization import WitConfigBuilder
from witwidget.notebook.visualization import WitWidget

# %% [markdown]
# # Download and Understand the Data

# %% [markdown]
# In this exercise, you'll work with the Civil Comments dataset, approximately 2 million public comments made public by the Civil Comments platform in 2017. Additionally, a subset of comments have been labelled with a variety of identity attributes, representing the identities that are mentioned in the comment.
#
# We've hosted the dataset on Google Cloud Platform for convenience. Run the following code to download the data from GCP, the data will take about a minute to download and analyze.
#
# TensorFlow Data Validation is one tool you can use to analyze your data. You can use it to find potential problems in your data, such as missing values and data imbalances, that can lead to Fairness disparities.

# %%
#@title Options for Dowloading data

#@markdown You can choose to download the original and process the data in
#@markdown the colab, which may take minutes. By default, we will download the
#@markdown data that we have already prepocessed for you. In the original
#@markdown dataset, for each indentity annotation columns, the value represents
#@markdown the percent of raters who thought the comment references the identity.
#@markdown When processing the raw data, the threshold 0.5 is chosen and the
#@markdown identities are grouped together by their categories. For example
#@markdown if one comment has { male: 0.3, female: 1.0, transgender: 0.0,
#@markdown heterosexual: 0.8, homosexual_gay_or_lesbian: 1.0 }, after the
#@markdown processing, the data will be { gender: [female], 
#@markdown sexual_orientation: [heterosexual, homosexual_gay_or_lesbian] }.
download_original_data = True #@param {type:"boolean"}

if download_original_data:
  train_tf_file = tf.keras.utils.get_file('train_tf.tfrecord',
                                          'https://storage.googleapis.com/civil_comments_dataset/train_tf.tfrecord')
  validate_tf_file = tf.keras.utils.get_file('validate_tf.tfrecord',
                                             'https://storage.googleapis.com/civil_comments_dataset/validate_tf.tfrecord')

  # The identity terms list will be grouped together by their categories
  # (see 'IDENTITY_COLUMNS') on threshould 0.5. Only the identity term column,
  # text column and label column will be kept after processing.
  train_tf_file = util.convert_comments_data(train_tf_file)
  validate_tf_file = util.convert_comments_data(validate_tf_file)

else:
  train_tf_file = tf.keras.utils.get_file('train_tf_processed.tfrecord',
                                          'https://storage.googleapis.com/civil_comments_dataset/train_tf_processed.tfrecord')
  validate_tf_file = tf.keras.utils.get_file('validate_tf_processed.tfrecord',
                                             'https://storage.googleapis.com/civil_comments_dataset/validate_tf_processed.tfrecord')

# %%
stats = tfdv.generate_statistics_from_tfrecord(data_location=train_tf_file)
tfdv.visualize_statistics(stats)
# Out:
# WARNING:root:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:366: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:366: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# There are several interesting things that we may want to note in this data. The first is that the toxicity label, which is what we are predicting, is unbalanced. Only 8% of examples in the training set are toxic, which means that a classifier could get 92% accuracy by predicting that all comments are non-toxic.
#
# For the fields relating to identity terms note that out of 1.08 million training examples, only around 6.6k examples deal with homosexuality, and those related to bisexuality are even more rare. This might indicate that performance on these slices may suffer due to lack of training data.

# %% [markdown]
# # Defining Constants

# %% [markdown]
# Here, we define the feature map that will be used to parse the data. Each example will have a label, comment text, and identity features `sexual orientation`, `gender`, `religion`, `race`, and `disability` that are associated with the text.

# %%
BASE_DIR = tempfile.gettempdir()

TEXT_FEATURE = 'comment_text'
LABEL = 'toxicity'
FEATURE_MAP = {
    # Label:
    LABEL: tf.io.FixedLenFeature([], tf.float32),
    # Text:
    TEXT_FEATURE:  tf.io.FixedLenFeature([], tf.string),

    # Identities:
    'sexual_orientation':tf.io.VarLenFeature(tf.string),
    'gender':tf.io.VarLenFeature(tf.string),
    'religion':tf.io.VarLenFeature(tf.string),
    'race':tf.io.VarLenFeature(tf.string),
    'disability':tf.io.VarLenFeature(tf.string),
}

# %% [markdown]
# # Train the Model

# %% [markdown]
# First, set up the input function to feed data into the model. Note that since we identified a class imbalance by our earlier TensorFlow Data Validation run, we will add a weight column to each example and upweight the toxic examples to account for this. We only use identity features during the evaluation phase, as only the comments are fed into the model at training time.

# %%
def train_input_fn():
  def parse_function(serialized):
    parsed_example = tf.io.parse_single_example(
        serialized=serialized, features=FEATURE_MAP)
    # Adds a weight column to deal with unbalanced classes.
    parsed_example['weight'] = tf.add(parsed_example[LABEL], 0.1)
    return (parsed_example,
            parsed_example[LABEL])
  train_dataset = tf.data.TFRecordDataset(
      filenames=[train_tf_file]).map(parse_function).batch(512)
  return train_dataset

# %% [markdown]
# Next, create a deep neural network model, and train it on the data:

# %%
model_dir = os.path.join(BASE_DIR, 'train', datetime.now().strftime(
    "%Y%m%d-%H%M%S"))

embedded_text_feature_column = hub.text_embedding_column(
    key=TEXT_FEATURE,
    module_spec='https://tfhub.dev/google/nnlm-en-dim128/1')

classifier = tf.estimator.DNNClassifier(
    hidden_units=[500, 100],
    weight_column='weight',
    feature_columns=[embedded_text_feature_column],
    optimizer=tf.optimizers.Adagrad(learning_rate=0.003),
    loss_reduction=tf.losses.Reduction.SUM,
    n_classes=2,
    model_dir=model_dir)

classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/train/20200114-144507', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/train/20200114-144507', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/train/20200114-144507/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/train/20200114-144507/model.ckpt.
# INFO:tensorflow:loss = 59.409668, step = 0
# INFO:tensorflow:loss = 59.409668, step = 0
# INFO:tensorflow:global_step/sec: 15.219
# INFO:tensorflow:global_step/sec: 15.219
# INFO:tensorflow:loss = 56.48169, step = 100 (6.574 sec)
# INFO:tensorflow:loss = 56.48169, step = 100 (6.574 sec)
# INFO:tensorflow:global_step/sec: 15.3735
# INFO:tensorflow:global_step/sec: 15.3735
# INFO:tensorflow:loss = 47.65094, step = 200 (6.504 sec)
# INFO:tensorflow:loss = 47.65094, step = 200 (6.504 sec)
# INFO:tensorflow:global_step/sec: 15.1118
# INFO:tensorflow:global_step/sec: 15.1118
# INFO:tensorflow:loss = 56.018814, step = 300 (6.618 sec)
# INFO:tensorflow:loss = 56.018814, step = 300 (6.618 sec)
# INFO:tensorflow:global_step/sec: 14.5088
# INFO:tensorflow:global_step/sec: 14.5088
# INFO:tensorflow:loss = 55.61124, step = 400 (6.892 sec)
# INFO:tensorflow:loss = 55.61124, step = 400 (6.892 sec)
# INFO:tensorflow:global_step/sec: 16.0508
# INFO:tensorflow:global_step/sec: 16.0508
# INFO:tensorflow:loss = 41.690742, step = 500 (6.230 sec)
# INFO:tensorflow:loss = 41.690742, step = 500 (6.230 sec)
# INFO:tensorflow:global_step/sec: 15.925
# INFO:tensorflow:global_step/sec: 15.925
# INFO:tensorflow:loss = 45.397655, step = 600 (6.278 sec)
# INFO:tensorflow:loss = 45.397655, step = 600 (6.278 sec)
# INFO:tensorflow:global_step/sec: 15.6115
# INFO:tensorflow:global_step/sec: 15.6115
# INFO:tensorflow:loss = 51.053444, step = 700 (6.407 sec)
# INFO:tensorflow:loss = 51.053444, step = 700 (6.407 sec)
# INFO:tensorflow:global_step/sec: 16.3284
# INFO:tensorflow:global_step/sec: 16.3284
# INFO:tensorflow:loss = 47.318947, step = 800 (6.122 sec)
# INFO:tensorflow:loss = 47.318947, step = 800 (6.122 sec)
# INFO:tensorflow:global_step/sec: 19.6923
# INFO:tensorflow:global_step/sec: 19.6923
# INFO:tensorflow:loss = 48.317566, step = 900 (5.081 sec)
# INFO:tensorflow:loss = 48.317566, step = 900 (5.081 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/train/20200114-144507/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/train/20200114-144507/model.ckpt.
# INFO:tensorflow:Loss for final step: 50.760162.
# INFO:tensorflow:Loss for final step: 50.760162.

# %% [markdown]
# # Run TensorFlow Model Analysis with Fairness Indicators

# %% [markdown]
# ## Export Saved Model

# %%
def eval_input_receiver_fn():
  serialized_tf_example = tf.compat.v1.placeholder(
      dtype=tf.string, shape=[None], name='input_example_placeholder')

  # This *must* be a dictionary containing a single key 'examples', which
  # points to the input placeholder.
  receiver_tensors = {'examples': serialized_tf_example}

  features = tf.io.parse_example(serialized_tf_example, FEATURE_MAP)
  features['weight'] = tf.ones_like(features[LABEL])

  return tfma.export.EvalInputReceiver(
    features=features,
    receiver_tensors=receiver_tensors,
    labels=features[LABEL])

tfma_export_dir = tfma.export.export_eval_savedmodel(
  estimator=classifier,
  export_dir_base=os.path.join(BASE_DIR, 'tfma_eval_model'),
  eval_input_receiver_fn=eval_input_receiver_fn)
# Out:
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_model_analysis/eval_saved_model/encoding.py:141: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_model_analysis/eval_saved_model/encoding.py:141: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: ['eval']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: ['eval']
# WARNING:tensorflow:Export includes no default signature!
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from /tmp/train/20200114-144507/model.ckpt-1000
# INFO:tensorflow:Restoring parameters from /tmp/train/20200114-144507/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets written to: /tmp/tfma_eval_model/temp-b'1579041973'/assets
# INFO:tensorflow:Assets written to: /tmp/tfma_eval_model/temp-b'1579041973'/assets
# INFO:tensorflow:SavedModel written to: /tmp/tfma_eval_model/temp-b'1579041973'/saved_model.pb
# INFO:tensorflow:SavedModel written to: /tmp/tfma_eval_model/temp-b'1579041973'/saved_model.pb

# %% [markdown]
# ## Compute Fairness Metrics

# %% [markdown]
# Select the identity to compute metrics for and whether to run with confidence intervals in the panel on the right-hand side. Depending on your configurations, this step will take 2-10 minutes to run.

# %%
#@title Fairness Indicators Computation Options
tfma_eval_result_path = os.path.join(BASE_DIR, 'tfma_eval_result')

#@markdown Modify the slice_selection for experiments on other identities.
slice_selection = 'sexual_orientation' #@param ["sexual_orientation", "gender", "religion", "race", "disability"]
#@markdown Confidence Intervals can help you make better decisions regarding your data, but as it requires computing multiple resamples, is slower particularly in the colab environment that cannot take advantage of parallelization.
compute_confidence_intervals = False #@param {type:"boolean"}

# Define slices that you want the evaluation to run on.
slice_spec = [
    tfma.slicer.SingleSliceSpec(), # Overall slice
    tfma.slicer.SingleSliceSpec(columns=[slice_selection]),
]

# Add the fairness metrics.
add_metrics_callbacks = [
  tfma.post_export_metrics.fairness_indicators(
      thresholds=[0.1, 0.3, 0.5, 0.7, 0.9],
      labels_key=LABEL
      )
]

eval_shared_model = tfma.default_eval_shared_model(
    eval_saved_model_path=tfma_export_dir,
    add_metrics_callbacks=add_metrics_callbacks)

# Run the fairness evaluation.
with beam.Pipeline() as pipeline:
  _ = (
      pipeline
      | 'ReadData' >> beam.io.ReadFromTFRecord(validate_tf_file)
      | 'ExtractEvaluateAndWriteResults' >>
       tfma.ExtractEvaluateAndWriteResults(
                 eval_shared_model=eval_shared_model,
                 slice_spec=slice_spec,
                 compute_confidence_intervals=compute_confidence_intervals,
                 output_path=tfma_eval_result_path)
  )

eval_result = tfma.load_eval_result(output_path=tfma_eval_result_path)
# Out:
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_model_analysis/eval_saved_model/load.py:169: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_model_analysis/eval_saved_model/load.py:169: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from /tmp/tfma_eval_model/1579041973/variables/variables
# INFO:tensorflow:Restoring parameters from /tmp/tfma_eval_model/1579041973/variables/variables
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_model_analysis/eval_saved_model/graph_ref.py:189: get_tensor_from_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.get_tensor_from_tensor_info or tf.compat.v1.saved_model.get_tensor_from_tensor_info.
# WARNING:tensorflow:From /usr/local/google/home/karanshukla/.env/JikHqXDZLJIPfde584ewDazHVCAZ52AU/lib/python3.7/site-packages/tensorflow_model_analysis/eval_saved_model/graph_ref.py:189: get_tensor_from_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.get_tensor_from_tensor_info or tf.compat.v1.saved_model.get_tensor_from_tensor_info.
# WARNING:root:Deleting 1 existing files in target path matching:
# WARNING:root:Deleting 1 existing files in target path matching:
# WARNING:root:Deleting 1 existing files in target path matching:

# %% [markdown]
# # Render What-if Tool

# %% [markdown]
# In this section, you'll use the [What-If Tool's ](https://pair-code.github.io/what-if-tool/)interactive visual interface to explore and manipulate data at a micro-level.
#
# On the right-hand panel in the visualization, you will see a scatter plot where each point represents one of the examples in the subset loaded into the tool. Click on one of the points. In the left-hand panel, you should now see details about this particular example. The comment text, ground truth toxicity, and applicable identities are shown. At the bottom of this left-hand panel, you see the inference results from the model you just trained.
#
# Modify the text of the example. You can then click the "Run inference" button to view how your changes caused the perceived toxicity prediction to change.

# %%
DEFAULT_MAX_EXAMPLES = 1000

# Load 100000 examples in memory. When first rendered, 
# What-If Tool should only display 1000 of these due to browser constraints.
def wit_dataset(file, num_examples=100000):
  dataset = tf.data.TFRecordDataset(
      filenames=[file]).take(num_examples)
  return [tf.train.Example.FromString(d.numpy()) for d in dataset]

wit_data = wit_dataset(train_tf_file)
config_builder = WitConfigBuilder(wit_data[:DEFAULT_MAX_EXAMPLES]).set_estimator_and_feature_spec(
    classifier, FEATURE_MAP).set_label_vocab(['non-toxicity', LABEL]).set_target_feature(LABEL)
wit = WitWidget(config_builder)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Render Fairness Indicators
#
# Render the Fairness Indicators widget with the exported evaluation results.
#
# Below you will see bar charts displaying performance of each slice of the data on selected metrics. You can adjust the baseline comparison slice as well as the displayed threshold(s) using the drop down menus at the top of the visualization.
#
# The Fairness Indicator widget is integrated with the What-If Tool rendered above. If you select one slice of the data in the bar chart, the What-If Tool will update to show you examples from the selected slice. When the data reloads in the What-If Tool above, try modifying **Color By** to **toxicity**. This can give you a visual understanding of the toxicity balance of examples by slice.

# %%
event_handlers={'slice-selected':
                wit.create_selection_callback(wit_data, DEFAULT_MAX_EXAMPLES)}
widget_view.render_fairness_indicator(eval_result,
                                      slicing_column=slice_selection,
                                      event_handlers=event_handlers)
# Out:
# FairnessIndicatorViewer(slicingMetrics=[{'sliceValue': 'Overall', 'slice': 'Overall', 'metrics': {'post_export…

# %% [markdown]
# With this particular dataset and task, systematically higher false positive and false negative rates for certain identities can lead to negative consequences. For example, in a content moderation system, a higher-than-overall false positive rate for a certain group can lead to those voices being silenced. Thus, it is important to regularly evaluate these types of criteria as you develop and improve models, and utilize tools such as Fairness Indicators, TFDV, and WIT to help illuminate potential problems. Once you've identified fairness issues, you can experiment with new data sources, data balancing, or other techniques to improve performance on underperforming groups.
#
# For more information and guidance on how Fairness Indicators can be used, see [this link](https://bit.ly/fairness-indicators-guidance).
